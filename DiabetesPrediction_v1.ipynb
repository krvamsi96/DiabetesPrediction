# %% [markdown]
# # Diabetes Prediction

# %%
import pandas as pd
import numpy as np

# %%
dfMain=pd.read_csv("E:\DataScience\Assignment2\Diabetes.csv")
df_train, df_test = np.split(dfMain.sample(frac=1),[int(.7*len(dfMain))])

# %%
df_train.head()
len(df_train)
# Out:
# 537

# %%
df_train.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 298           14      100             78             25      184  36.6
# 482            4       85             58             22       49  27.8
# 64             7      114             66              0        0  32.8
# 433            2      139             75              0        0  25.6
# 440            0      189            104             25        0  34.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 298                     0.412   46        1
# 482                     0.306   28        0
# 64                      0.258   42        1
# 433                     0.167   29        0
# 440                     0.435   41        1

# %%
df_train.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count    537.00000  537.000000     537.000000     537.000000  537.000000
# mean       3.75419  122.184358      69.024209      20.411546   84.100559
# std        3.32717   33.008331      19.289366      15.771931  122.323834
# min        0.00000    0.000000       0.000000       0.000000    0.000000
# 25%        1.00000  100.000000      64.000000       0.000000    0.000000
# 50%        3.00000  119.000000      72.000000      23.000000   37.000000
# 75%        6.00000  143.000000      80.000000      32.000000  128.000000
# max       15.00000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  537.000000                537.000000  537.000000  537.000000
# mean    32.113222                  0.474378   33.167598    0.368715
# std      7.508962                  0.332496   11.764077    0.482906
# ...

# %%
import matplotlib.pyplot as plt

# %%
df_train.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.134787       0.162535      -0.102381
# Glucose                      0.134787  1.000000       0.135209       0.025155
# BloodPressure                0.162535  0.135209       1.000000       0.208304
# SkinThickness               -0.102381  0.025155       0.208304       1.000000
# Insulin                     -0.101549  0.316716       0.107303       0.425149
# BMI                          0.005634  0.212963       0.269660       0.385550
# DiabetesPedigreeFunction    -0.056555  0.116144       0.036502       0.157576
# Age                          0.545583  0.245794       0.248293      -0.141689
# Outcome                      0.212112  0.456529       0.008453       0.018743
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.101549  0.005634                 -0.056555
# ...

# %%
P=df_train['Pregnancies']
G=df_train['Glucose']
BP=df_train['BloodPressure']
ST=df_train['SkinThickness']
I=df_train['Insulin']
BMI=df_train['BMI']
DPF=df_train['DiabetesPedigreeFunction']
AGE=df_train['Age']
Outcome=df_train['Outcome']

# %%
plt.hist(P)
plt.title('Pregnancies')
plt.show()

# %%
plt.hist(G)
plt.title('Glucose')
plt.show()

# %%
plt.hist(BP)
plt.title('BloodPressure')
plt.show()

# %%
plt.hist(ST)
plt.title('SkinThickness')
plt.show()

# %%
plt.hist(I)
plt.title('Insulin')
plt.show()

# %%
plt.hist(BMI)
plt.title('BMI')
plt.show()

# %%
plt.hist(DPF)
plt.title('DiabetesPedigreeFunction')
plt.show()

# %%
plt.hist(AGE)
plt.title('Age')
plt.show()

# %%
plt.hist(Outcome)
plt.title('Outcome')
plt.show()

# %%
plt.scatter(AGE, Outcome)
plt.title('Age vs outcome')
plt.show()

# %%
plt.scatter(DPF, Outcome)
plt.title('Pedigree value vs outcome')
plt.show()

# %%
plt.scatter(Outcome, G)
plt.title('Glucose vs outcome')
plt.show()

# %%
plt.scatter(I, ST)
plt.title('Insulin vs Skinthickness')
plt.show()

# %%
colors = {0:'blue', 1:'red'}

# %%
plt.scatter(G, AGE, c=Outcome.apply(lambda Outcome: colors[Outcome]))
plt.title('Glucose, Age vs outcome')
plt.show()

# %%
plt.scatter(G, BMI, c=Outcome.apply(lambda Outcome:colors[Outcome]))
plt.title('Glucose, BMI vs outcome')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="darkgrid", color_codes=True)
sns.FacetGrid(df_train, hue="Outcome", size=5) \
   .map(plt.scatter, "Glucose", "Age") \
   .add_legend()
plt.show()

# %%
sns.boxplot(x="Outcome", y="Glucose", data=df_train)
plt.show()

# %%
sns.boxplot(x="Outcome", y="Age", data=df_train)
plt.show()

# %%
sns.boxplot(x="Outcome", y="BMI", data=df_train)
plt.show()

# %%
sns.boxplot(x="Outcome", y="SkinThickness", data=df_train)
plt.show()

# %%
sns.FacetGrid(df_train, hue="Outcome", size=6) \
   .map(sns.kdeplot, "Glucose") \
   .add_legend()
plt.show()

# %%
sns.FacetGrid(df_train, hue="Outcome", size=6) \
   .map(sns.kdeplot, "BMI") \
   .add_legend()
plt.show()

# %%
sns.FacetGrid(df_train, hue="Outcome", size=6) \
   .map(sns.kdeplot, "Age") \
   .add_legend()
plt.show()

# %%
sns.pairplot(df_train, hue="Outcome", size=2)
plt.show()

# %%
df_train.boxplot(by="Outcome", figsize=(12, 8))
plt.show()

# %%
import numpy as np
dfMain['glBin'] = np.where(dfMain['Glucose']>=125,'Diabetic','Non-Diabetic')

# %%
dfMain.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome         glBin
# 0                     0.627   50        1      Diabetic
# 1                     0.351   31        0  Non-Diabetic
# 2                     0.672   32        1      Diabetic
# 3                     0.167   21        0  Non-Diabetic
# 4                     2.288   33        1      Diabetic

# %%
pd.pivot_table(dfMain, values="Glucose", index=["glBin"], columns = "Outcome", aggfunc="count", fill_value=0 )
# Out:
# Outcome         0    1
# glBin
# Diabetic      128  183
# Non-Diabetic  372   85

# %%
df_train['glBin'] = np.where(df_train['Glucose']>=125,'Diabetic','Non-Diabetic')

# %%
pd.pivot_table(df_train, values="Glucose", index=["glBin"], columns="Outcome", aggfunc="count", fill_value=0)
# Out:
# Outcome         0    1
# glBin
# Diabetic       91  139
# Non-Diabetic  248   59

# %%
df_test['glBin'] = np.where(df_test['Glucose']>=125,'Diabetic','Non-Diabetic')

# %%
pd.pivot_table(df_test, values="Glucose", index=["glBin"], columns="Outcome", aggfunc="count", fill_value=0)
# Out:
# Outcome         0   1
# glBin
# Diabetic       37  44
# Non-Diabetic  124  26
